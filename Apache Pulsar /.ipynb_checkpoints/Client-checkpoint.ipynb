# %%
import pulsar
import json
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import clear_output

# %%
client = pulsar.Client('pulsar://localhost:6650')

# %%
producer = client.create_producer('request')
# Out:
# 2022-05-31 14:26:54.000 INFO  [139691246778176] ConnectionPool:85 | Created connection for pulsar://localhost:6650
# 2022-05-31 14:26:54.011 INFO  [139690292909824] ClientConnection:356 | [127.0.0.1:58994 -> 127.0.0.1:6650] Connected to broker
# 2022-05-31 14:26:54.022 INFO  [139690292909824] HandlerBase:54 | [persistent://public/default/request, ] Getting connection from pool
# 2022-05-31 14:26:54.031 INFO  [139690292909824] ProducerImpl:170 | [persistent://public/default/request, ] Created producer on broker [127.0.0.1:58994 -> 127.0.0.1:6650]

# %%
total_data = 2000

# %%
test_stack = []

# Divides the request into batches and sends it to the analysis nodes
def makeRequest(data_size, batch_size=264):
    temp_total = data_size
    start_index = 0
    if not (0 < data_size < 365000):
        raise ValueError("Data Size not available!")
    while data_size > 0:
        if data_size - batch_size < 0:
            batch_size = data_size
        next_index = start_index
        next_index += batch_size
        producer.send((f"{start_index} - {next_index}").encode('utf-8'))
        #test_stack.append(f"{start_index} - {next_index}")
        start_index = next_index + 1
        data_size -= batch_size + 1

# %%
makeRequest(2000)

# %%
def aggregate_dicts(dict_a, dict_b):
    for key in dict_b.keys():
        if key not in dict_a.keys():
            dict_a[key] = int(dict_b[key])
        else:
            dict_a[key] += int(dict_b[key])
    return dict_a

def parse_dict(prog_dict):
    prog_df = pd.DataFrame.from_dict(prog_dict, orient='index', columns=["count"])
    prog_df = prog_df.sort_values("count", ascending=False)
    return prog_df

# %%
consumer_one = client.subscribe('response_one', subscription_name='client')
# Out:
# 2022-05-31 14:30:07.141 INFO  [139691246778176] Client:88 | Subscribing on Topic :response_one
# 2022-05-31 14:30:07.158 INFO  [139690292909824] HandlerBase:54 | [persistent://public/default/response_one, client, 0] Getting connection from pool
# 2022-05-31 14:30:07.165 INFO  [139690292909824] ConsumerImpl:216 | [persistent://public/default/response_one, client, 0] Created consumer on broker [127.0.0.1:58994 -> 127.0.0.1:6650]

# %%
prog_dict = {}
while True:
    #merge top ranking programming languages
    msg = json.loads(consumer_one.receive().data().decode("utf-8"))
    prog_dict = aggregate_dicts(prog_dict, msg)
    clear_output(wait=True)
    print(parse_dict(prog_dict))
# Out:
#                   count
# SCSS                  1
# SMT                   1
# SourcePawn            1
# GDScript              1
# Pascal                1
# TeX                   1
# PowerShell            1
# Assembly              1
# OpenSCAD              1
# Crystal               1
# HCL                   1
# Scala                 1
# Ruby                  1
# Vim script            1
# Racket                1
# Haskell               1
# Solidity              1
# EJS                   1
# Pug                   1
# Cuda                  1
# Svelte                1
# MATLAB                2
# R                     2
# Makefile              2
# CSS                   3
# Objective-C           3
# Swift                 3
# Vue                   4
# Dart                  4
# Lua                   4
# PHP                   6
# Shell                 6
# Kotlin                7
# HTML                  9
# C#                    9
# C++                  10
# Go                   10
# C                    12
# Jupyter Notebook     14
# TypeScript           15
# Java                 15
# None                 22
# Python               40
# JavaScript           42
#                   count
# Dockerfile            1
# Pascal                1
# PowerShell            1
# MQL5                  1
# SourcePawn            1
# SMT                   1
# OpenSCAD              1
# Solidity              1
# Haskell               1
# Pug                   1
# Scala                 1
# Crystal               1
# TeX                   1
# CMake                 1
# Racket                1
# AutoHotkey            1
# Assembly              1
# EJS                   1
# Verilog               1
# Cuda                  1
# Clojure               1
# Batchfile             1
# Rust                  2
# GDScript              2
# SCSS                  2
# Svelte                2
# MATLAB                2
# HCL                   2
# Vim script            2
# Objective-C           3
# Ruby                  3
# Lua                   5
# Makefile              5
# Vue                   5
# Swift                 5
# Dart                  6
# R                     7
# Kotlin                7
# CSS                   8
# PHP                   8
# Shell                12
# C                    14
# C#                   15
# C++                  16
# Go                   19
# HTML                 20
# TypeScript           21
# Java                 24
# Jupyter Notebook     25
# None                 31
# Python               56
# JavaScript           60
#             count
# Julia           1
# Racket          1
# Scala           1
# Crystal         1
# OpenSCAD        1
# ...           ...
# C++            40
# TypeScript     42
# None           56
# JavaScript     86
# Python         97
#
# [64 rows x 1 columns]
#             count
# Jinja           1
# Crystal         1
# D               1
# Scala           1
# Pascal          1
# ...           ...
# C++            60
# TypeScript     64
# None           86
# JavaScript    112
# Python        146
#
# [66 rows x 1 columns]
#             count
# Elm             1
# Scala           1
# Racket          1
# EJS             1
# Pascal          1
# ...           ...
# C++            71
# TypeScript     79
# None          115
# JavaScript    158
# Python        189
#
# [71 rows x 1 columns]
#             count
# Haxe            1
# VHDL            1
# MQL5            1
# Max             1
# AutoHotkey      1
# ...           ...
# C++            83
# TypeScript    101
# None          143
# JavaScript    184
# Python        241
#
# [80 rows x 1 columns]
#             count
# OCaml           1
# SMT             1
# Jinja           1
# Pascal          1
# G-code          1
# ...           ...
# C++            95
# TypeScript    122
# None          170
# JavaScript    218
# Python        289
#
# [86 rows x 1 columns]
#             count
# Scheme          1
# SMT             1
# Elm             1
# HLSL            1
# XSLT            1
# ...           ...
# C++           104
# TypeScript    145
# None          191
# JavaScript    249
# Python        331
#
# [92 rows x 1 columns]
#             count
# Scheme          1
# Processing      1
# Elm             1
# HLSL            1
# TSQL            1
# ...           ...
# C++           114
# TypeScript    160
# None          213
# JavaScript    291
# Python        371
#
# [92 rows x 1 columns]
#                    count
# Scheme                 1
# Common Lisp            1
# Visual Basic .NET      1
# SuperCollider          1
# Processing             1
# ...                  ...
# C++                  120
# TypeScript           166
# None                 222
# JavaScript           309
# Python               387
#
# [92 rows x 1 columns]

# %%
data = {'row_1': [3], 'row_2': ['a']}
pd.DataFrame.from_dict(data, orient='index', columns=["test"])
# Out:
#       test
# row_1    3
# row_2    a

# %%
client.close()
